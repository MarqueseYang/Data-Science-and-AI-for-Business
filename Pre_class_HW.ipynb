# %% [markdown]
# <a href="https://colab.research.google.com/github/MarqueseYang/Data-Science-and-AI-for-Business/blob/main/Pre_class_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pre-class Homework - Survey and Python review
#
# Welcome to the course! The purpose of this homework is to get to know you better and warm up your Python skills before the first class. Make sure to check out the referesher in Module0_Basics if it has been a while since the last time you coded.
#
# Please upload your completed notebook to Brightspace.

# %% [markdown]
# ## Part 0: I have gone through the [Colab Basics Jupyter Notebook](http://www.github.com/dz-web3/DS-Tech-2026spring/blob/main/Module0_Basics/Colab_Basics.ipynb)

# %% [markdown]
# **Mark "Yes" below.**

# %% [markdown]
# _YES_  I saved this Colab notebook and deleted the relevant cell above
#
# _YES_  I have read and understood the Colab notebook

# %% [markdown]
# ## Part 1: Know the course

# %% [markdown]
# **1.1 Read the syllabus (available on Brightspace) in its entirety. Mark "Yes" below.**

# %% [markdown]
# YES I have read and understood the syllabus for this class.

# %% [markdown]
# ## Part 2: Let us know you better

# %% [markdown]
# **2.1 Please go to this [link](https://docs.google.com/forms/d/e/1FAIpQLScdWHCeTHZIJLBBukXoX4lMYWvkzAbHIkw4I14iMqqEv4MGAg/viewform?usp=dialog) and fill the survey. Mark "Yes" below.**

# %% [markdown]
# YES I have read and filled the survey for this class.

# %% [markdown]
# ## Part 3: Python review
# > **Important: Please DO NOT use ANY AI assistance to complete this review. You need to be able to do this sort of Python work on your own to succeed in this class.**

# %% [markdown]
# **3.1 Create one Python list of 5 unique fruits and another one with 5 unique colors.**

# %%
fruits = ["apple","banana","pear","pineapple","watermelon"]
colors = ["black","white","grey","green","yellow"]

# %% [markdown]
# **3.2 Go through each fruit (first list) and print out the name of the fruit with one color of the second list without repeating any color.**
#
# (don't worry, it doesn't have to be the color of the fruit!)
#
# Example of what you should print for one fruit:  _apple is purple_

# %%
for fruit, color in zip(fruits,colors):
  print(f"{fruit} is {color}")
# Out:
# apple is black
# banana is white
# pear is grey
# pineapple is green
# watermelon is yellow

# %% [markdown]
# **3.3 Add two new fruits to your list with a _BUILT-IN_ function.**
#
# (You may want to look for the function with the **TAB** hint!)

# %%
fruits.append("blueberry")
fruits.append("strawberry")

# %% [markdown]
# **3.4 Use the list of fruits and sort the names (put them in alphabetical order).**
#
# (Hint: The lists in Python already have a function for that)

# %%
fruits.sort()
print(fruits)
# Out:
# ['apple', 'banana', 'blueberry', 'pear', 'pineapple', 'strawberry', 'watermelon']

# %% [markdown]
# **3.5 Create a new empty list called "count_letters". Go through your list of fruits, and for each one, add an entry to that new list (count_letters) telling the number of letters each fruit name. Then, print how many letters each fruit has.**
#
# Example of what you should print for one fruit: _apple is 5 letters_

# %%
count_letters = []
for fruit in fruits:
  length = len(fruit)
  count_letters.append(length)
  print(f"{fruit} is {length} letters")
# Out:
# apple is 5 letters
# banana is 6 letters
# blueberry is 9 letters
# pear is 4 letters
# pineapple is 9 letters
# strawberry is 10 letters
# watermelon is 10 letters

# %% [markdown]
# **3.6 Make a function called `one_more` that takes a list (input_list) and returns a new list (output_list) where each element of the original will be increased by 1 and divided by 2.**

# %%
def one_more(input_list):
    output_list = []
    for number in input_list:
      result = (number+1)/2
      output_list.append(result)
    return output_list

# %% [markdown]
# **3.7 Use the previous function to change the value of a list of 10 random numbers.**

# %%
import random
numbers = [random.randint(1, 100) for _ in range(10)]
transformed_numbers = one_more(numbers)
print("Original List:   ", numbers)
print("Transformed List:", transformed_numbers)
# Out:
# Original List:    [54, 94, 56, 35, 42, 73, 10, 68, 2, 10]
# Transformed List: [27.5, 47.5, 28.5, 18.0, 21.5, 37.0, 5.5, 34.5, 1.5, 5.5]

# %% [markdown]
# # To submit the homework save it to your google drive (see Part 0), download it and upload to Brightspace under assignments
